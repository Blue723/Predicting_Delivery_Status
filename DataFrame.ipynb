# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
from sklearn.preprocessing import OneHotEncoder

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Supply Chain Data/DataCoSupplyChainDataset.csv')

# %%
# y value delivery status, categorically able to predict if a delivery is
# late, advanced/ a head of schedule, on time, or was canceled. 
df['Delivery Status'].value_counts()
# Out:
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: Delivery Status, dtype: int64

# %%
df.drop(columns=[
    'Category Name',
    'Customer City',
    'Customer Country',
    'Customer Email',
    'Customer Fname',
    'Customer Id',
    'Customer Lname',
    'Customer Password',
    'Customer Street',
    'Order Item Cardprod Id',
    'Product Card Id',
    'Product Category Id',
    'Product Description',
    'Product Status',
    'Product Image',
    'Product Name',
    'Order Zipcode'
], axis=1, inplace=True)

# %%
for c in df.columns:
    print(c)
    print(df[c].isna().sum())
# Out:
# Type
# 0
# Days for shipping (real)
# 0
# Days for shipment (scheduled)
# 0
# Benefit per order
# 0
# Sales per customer
# 0
# Delivery Status
# 0
# Late_delivery_risk
# 0
# Category Id
# 0
# Customer Segment
# 0
# Customer State
# 0
# Customer Zipcode
# 3
# Department Id
# 0
# Department Name
# 0
# Latitude
# 0
# Longitude
# 0
# Market
# 0
# Order City
# 0
# Order Country
# 0
# Order Customer Id
# 0
# order date (DateOrders)
# 0
# Order Id
# 0
# Order Item Discount
# 0
# Order Item Discount Rate
# 0
# Order Item Id
# 0
# Order Item Product Price
# 0
# Order Item Profit Ratio
# 0
# Order Item Quantity
# 0
# Sales
# 0
# Order Item Total
# 0
# Order Profit Per Order
# 0
# Order Region
# 0
# Order State
# 0
# Order Status
# 0
# Product Price
# 0
# shipping date (DateOrders)
# 0
# Shipping Mode
# 0

# %%
df[df['Customer Zipcode'].isna() == True]
# Out:
#           Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 35704    DEBIT                         2                              1
# 46440  PAYMENT                         4                              4
# 82511    DEBIT                         4                              4
#
#        Benefit per order  Sales per customer   Delivery Status  \
# 35704          66.379997          189.660004     Late delivery
# 46440          10.910000           38.959999  Shipping on time
# 82511          59.990002          299.959992  Shipping on time
#
#        Late_delivery_risk  Category Id Customer Segment Customer State  ...  \
# 35704                   1           65         Consumer          95758  ...
# 46440                   0           75        Corporate          95758  ...
# 82511                   0           63         Consumer          91732  ...
#
#        Order Item Quantity       Sales Order Item Total  \
# 35704                    1  252.880005       189.660004
# 46440                    1   39.750000        38.959999
# 82511                    1  357.100006       299.959992
#
#        Order Profit Per Order     Order Region            Order State  \
# 35704               66.379997   Western Europe  Auvernia-R�dano-Alpes
# 46440               10.910000   Southeast Asia       Capital Nacional
# 82511               59.990002  Northern Europe             Inglaterra
#
#           Order Status Product Price  shipping date (DateOrders)  \
# 35704         COMPLETE    252.880005             11/4/2017 18:31
# 46440  PENDING_PAYMENT     39.750000            12/14/2017 15:18
# 82511         COMPLETE    357.100006             10/30/2017 0:29
#
#         Shipping Mode
# 35704     First Class
# 46440  Standard Class
# 82511  Standard Class
#
# [3 rows x 36 columns]

# %%
#clean customer zipcode
df.drop(index=[35704, 46440, 82511], axis=0, inplace=True)

# %% [markdown]
# ##### Converting Date to Year-Month

# %%
#order date
date_od = pd.to_datetime(pd.Series(df['order date (DateOrders)'], )).dt.strftime('%Y-%m')

# %%
df = pd.concat([df, date_od], axis=1)
df['order date y-m'] = df['order date (DateOrders)'].iloc[:, 1]
df.drop(columns=['order date (DateOrders)'], axis=1, inplace=True)

# %%
#shipping date
date_sd = pd.to_datetime(pd.Series(df['shipping date (DateOrders)'])).dt.strftime('%Y-%m')

# %%
df = pd.concat([df, date_sd], axis=1)
df['shipping date y-m'] = df['shipping date (DateOrders)'].iloc[:, 1]
df.drop(columns=['shipping date (DateOrders)'], axis=1, inplace=True)

# %%
#dropping shipping cancelled rows. 
df = df[df['Delivery Status'] != 'Shipping canceled' ]

# %%
#reset index
df.reset_index(drop=True, inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.sort_values(by=['order date y-m', 'shipping date y-m'], inplace=True)

# %%
df = df.drop(columns=[
    'Days for shipping (real)',
    'Benefit per order',
    'Category Id',
    'Customer State',
    'Order State',
    'Order Item Total',
    'Order Customer Id',
    'Order Id',
    'Order City',
    'Order Country',
    'Order Status',
    'Product Price',
], axis=1)

# %%
df.to_csv('df.csv')

# %%
#setting advance shipping status to on time to see if the model is 
#predicitng simply if we care the package is on time or not.

df_ontime_vs_late = df.replace(to_replace='Advance shipping', value='Shipping on time')
df_ontime_vs_late
# Out:
#             Type  Days for shipment (scheduled)  Sales per customer  \
# 101     TRANSFER                              4          167.960007
# 131     TRANSFER                              4          283.450012
# 314     TRANSFER                              4           71.980003
# 637     TRANSFER                              4          169.960007
# 645     TRANSFER                              4          230.350006
# ...          ...                            ...                 ...
# 166386      CASH                              4          209.350006
# 166433      CASH                              4          183.449997
# 166455      CASH                              4          176.970001
# 168052     DEBIT                              1          183.449997
# 168159     DEBIT                              1          179.130005
#
#          Delivery Status  Late_delivery_risk Customer Segment  \
# 101     Shipping on time                   0         Consumer
# 131        Late delivery                   1         Consumer
# 314     Shipping on time                   0        Corporate
# 637     Shipping on time                   0         Consumer
# 645        Late delivery                   1         Consumer
# ...                  ...                 ...              ...
# 166386     Late delivery                   1         Consumer
# 166433     Late delivery                   1         Consumer
# 166455     Late delivery                   1         Consumer
# 168052     Late delivery                   1         Consumer
# 168159     Late delivery                   1         Consumer
#
#         Customer Zipcode  Department Id Department Name   Latitude  ...  \
# 101                725.0              5            Golf  18.253332  ...
# 131                725.0              4         Apparel  18.292149  ...
# 314              94541.0              5            Golf  37.675510  ...
# 637                725.0              5            Golf  18.202093  ...
# 645                725.0              6        Outdoors  18.215712  ...
# ...                  ...            ...             ...        ...  ...
# 166386             725.0              4         Apparel  18.289610  ...
# 166433             725.0              4         Apparel  18.239115  ...
# 166455             725.0              4         Apparel  18.209925  ...
# 168052             725.0              4         Apparel  18.229307  ...
# 168159             725.0              4         Apparel  18.289902  ...
#
#         Order Item Id Order Item Product Price  Order Item Profit Ratio  \
# 101              2420                39.990002                     0.50
# 131               989                59.990002                    -0.55
# 314               922                39.990002                     0.33
# 637              3424                39.990002                     0.08
# 645              2749                47.990002                    -0.06
# ...               ...                      ...                      ...
# 166386         180475               215.820007                     0.26
# 166433         180160               215.820007                     0.35
# 166455         180409               215.820007                     0.38
# 168052         180394               215.820007                     0.28
# 168159         180446               215.820007                     0.30
#
#         Order Item Quantity       Sales  Order Profit Per Order  \
# 101                       5  199.949997               83.980003
# 131                       5  299.950012             -155.899994
# 314                       2   79.980003               23.389999
# 637                       5  199.949997               13.260000
# 645                       5  239.949997              -14.280000
# ...                     ...         ...                     ...
# 166386                    1  215.820007               54.430000
# 166433                    1  215.820007               64.209999
# 166455                    1  215.820007               66.360001
# 168052                    1  215.820007               51.369999
# 168159                    1  215.820007               53.740002
#
#            Order Region   Shipping Mode  order date y-m  shipping date y-m
# 101           Caribbean  Standard Class         2015-01            2015-01
# 131     Central America  Standard Class         2015-01            2015-01
# 314       South America  Standard Class         2015-01            2015-01
# 637       South America  Standard Class         2015-01            2015-01
# 645           Caribbean  Standard Class         2015-01            2015-01
# ...                 ...             ...             ...                ...
# 166386     Eastern Asia  Standard Class         2018-01            2018-02
# 166433   Southeast Asia  Standard Class         2018-01            2018-02
# 166455       South Asia  Standard Class         2018-01            2018-02
# 168052       South Asia     First Class         2018-01            2018-02
# 168159   Southeast Asia     First Class         2018-01            2018-02
#
# [172762 rows x 24 columns]

# %%
#now only late delivery and shipping on time are considered in this dataframe
df_ontime_vs_late['Delivery Status'].value_counts()
# Out:
# Late delivery       98976
# Shipping on time    73786
# Name: Delivery Status, dtype: int64

# %%
df_ontime_vs_late.to_csv('df_ontime_vs_late.csv')

# %%
len(df_ontime_vs_late)
# Out:
# 172762
